# %% [markdown]
# ## Message Exceptions
#
# The SaveMessages class now has limited memory and should only be able to hold a maximum of 10 messages at once.
#
# This challenge has three parts, outlined in comments below.
#
# **\# 1. Finish creating the TooManyMessagesException class**
#
# Fill in the TooManyMessagesException class. Add a custom message!
#
# **\# 2. Raise a TooManyMessagesException exception here**
#
# Make sure that the SaveMessages class doesn't get over-full and raises an Exception if the max_messages limit is reached.
#
# **\# 3. Catch a TooManyMessagesException and print the messages**
#
# Modify this code so that, if an exception is raised when the message is sent, the messages are printed out (emptying the message list) and the message is re-sent. Make sure to print out any remaining messages at the end!

# %%
from datetime import datetime

def getCurrentTime():
    return datetime.now().strftime("%m-%d-%Y %H:%M:%S")


class Messenger:
    def __init__(self, listeners=None):
        self.listeners = listeners or []
    
    def send(self, message):
        for listener in self.listeners:
            listener.receive(message)

    def receive(self, message):
        pass

class TooManyMessagesException(Exception):
    def __init__(self):
        super().__init__('There are too many stored messages.')

class SaveMessages(Messenger):
    def __init__(self, listeners=[]):
        super().__init__(listeners)
        self.messages = []
        self.max_messages = 10
        
    def receive(self, message):
        if len(self.messages) >= self.max_messages:
            raise TooManyMessagesException()
        self.messages.append({'message': message, 'time': getCurrentTime()})
        
    def printMessages(self):
        for m in self.messages:
            print(f'Message: "{m["message"]}" Time: {m["time"]}')
        self.messages = []

# %%
listener = SaveMessages()
sender = Messenger([listener])
for i in range(0, 101):
    try:
        sender.send(f'This is message {i}')
    except TooManyMessagesException as e:
        listener.printMessages()
        print(e)
        sender.send(f'This is message {i}')
# Out:
# Message: "This is message 0" Time: 05-10-2024 10:40:49
# Message: "This is message 1" Time: 05-10-2024 10:40:49
# Message: "This is message 2" Time: 05-10-2024 10:40:49
# Message: "This is message 3" Time: 05-10-2024 10:40:49
# Message: "This is message 4" Time: 05-10-2024 10:40:49
# Message: "This is message 5" Time: 05-10-2024 10:40:49
# Message: "This is message 6" Time: 05-10-2024 10:40:49
# Message: "This is message 7" Time: 05-10-2024 10:40:49
# Message: "This is message 8" Time: 05-10-2024 10:40:49
# Message: "This is message 9" Time: 05-10-2024 10:40:49
# There are too many stored messages.
# Message: "This is message 10" Time: 05-10-2024 10:40:49
# Message: "This is message 11" Time: 05-10-2024 10:40:49
# Message: "This is message 12" Time: 05-10-2024 10:40:49
# Message: "This is message 13" Time: 05-10-2024 10:40:49
# Message: "This is message 14" Time: 05-10-2024 10:40:49
# Message: "This is message 15" Time: 05-10-2024 10:40:49
# Message: "This is message 16" Time: 05-10-2024 10:40:49
# Message: "This is message 17" Time: 05-10-2024 10:40:49
# Message: "This is message 18" Time: 05-10-2024 10:40:49
# Message: "This is message 19" Time: 05-10-2024 10:40:49
# There are too many stored messages.
# Message: "This is message 20" Time: 05-10-2024 10:40:49
# Message: "This is message 21" Time: 05-10-2024 10:40:49
# Message: "This is message 22" Time: 05-10-2024 10:40:49
# Message: "This is message 23" Time: 05-10-2024 10:40:49
# Message: "This is message 24" Time: 05-10-2024 10:40:49
# Message: "This is message 25" Time: 05-10-2024 10:40:49
# Message: "This is message 26" Time: 05-10-2024 10:40:49
# Message: "This is message 27" Time: 05-10-2024 10:40:49
# Message: "This is message 28" Time: 05-10-2024 10:40:49
# Message: "This is message 29" Time: 05-10-2024 10:40:49
# There are too many stored messages.
# Message: "This is message 30" Time: 05-10-2024 10:40:49
# Message: "This is message 31" Time: 05-10-2024 10:40:49
# Message: "This is message 32" Time: 05-10-2024 10:40:49
# Message: "This is message 33" Time: 05-10-2024 10:40:49
# Message: "This is message 34" Time: 05-10-2024 10:40:49
# Message: "This is message 35" Time: 05-10-2024 10:40:49
# Message: "This is message 36" Time: 05-10-2024 10:40:49
# Message: "This is message 37" Time: 05-10-2024 10:40:49
# Message: "This is message 38" Time: 05-10-2024 10:40:49
# Message: "This is message 39" Time: 05-10-2024 10:40:49
# There are too many stored messages.
# Message: "This is message